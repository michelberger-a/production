# %%
# %load_ext dotenv
# %dotenv

# %% [markdown]
# # What are we doing?
#
# ## Objectives
#
#
# * Build a data pipeline that downloads price data from the internet, stores it locally, transforms it into return data, and stores the feature set.
#     - Getting the data.
#     - Schemas and index in dask.
#
# * Explore the parquet format.
#     - Reading and writing parquet files.
#     - Read datasets that are stored in distributed files.
#     - Discuss dask vs pandas as a small example of big vs small data.
#
# * Discuss the use of environment variables for settings.
# * Discuss how to use Jupyter notebooks and source code concurrently.
# * Logging and using a standard logger.
#
# ## About the Data
#
# + We will download the prices for a list of stocks.
# + The source is Yahoo Finance and we will use the API provided by the library yfinance.
#
#
# ## Medallion Architecture
#
# + The architecture that we are thinking about is called Medallion by [DataBricks](https://www.databricks.com/glossary/medallion-architecture). It is an ELT type of thinking, although our data is well-structured.
#
# ![Medallion Architecture (DataBicks)](./images/02_medallion_architecture.png)
#
# + In our case, we would like to optimize the number of times that we download data from the internet.
# + Ultimately, we will build a pipeline manager class that will help us control the process of obtaining and transforming our data.
#
# ![](./images/02_target_pipeline_manager.png)

# %% [markdown]
# # Download Data from Yahoo Finance
#
# Yahoo Finance provides information about public stocks in different markets. The library yfinance gives us access to a fair bit of the data in Yahoo Finance.
#
# These steps are based on the instructions in:
#
# + [yfinance documentation](https://pypi.org/project/yfinance/)
# + [Tutorial in geeksforgeeks.org](https://www.geeksforgeeks.org/get-financial-data-from-yahoo-finance-with-python/)

# %% [markdown]
# + If required, install: `python -m pip install yfinance`.
# + To download the price history of a stock, first use the following setup:

# %%
import pandas as pd
import yfinance as yf
import os
import sys

sys.path.append(os.getenv('SRC_DIR'))

# %% [markdown]
# A few things to notice in the code chunk above:
#
# + Libraries are ordered from high-level to low-level libraries from the package manager (pip in this case, but could be conda, poetry, etc.)
# + The command `sys.path.append("../05_src/)` will add the `../05_src/` directory to the path in the Notebook's kernel. This way, we can use our modules as part of the notebook.
# + Local modules are imported at the end.
# + The function `get_logger()` is called with `__name__` as recommended by the documentation.

# %% [markdown]
# Now, to download the historical price data for a stock, we could use:

# %%
stock = yf.Ticker("AAPL")
px = stock.history(start = "2013-12-01", end = "2024-02-01")

# %% [markdown]
# ## Parametrize the download
#
# + Generally, we will look to separate every parameter and setting from functions.
# + If we had a few stocks, we could cycle through them. We need a place to store the list of tickers (a db or file, for example).
# + Store a csv file with a few stock tickers. The location of the file is a setting, the contents of this file are parameters.
# + Use **environment variables** to pass parameters.

# %%
ticker_file = os.getenv("TICKERS")
tickers = pd.read_csv(ticker_file).sample(50, random_state=42)

# %% [markdown]
# Collecting padas data frames
#
# + From the [documentation](https://pandas.pydata.org/docs/user_guide/merging.html):
#
# > [`concat()`](https://pandas.pydata.org/docs/reference/api/pandas.concat.html#pandas.concat) makes a full copy of the data, and iteratively reusing `concat()` can create unnecessary copies. Collect all DataFrame or Series objects in a list before using `concat()`.
#
# + We can string operation togethers using dot operations. Enclose the line in parenthesis and add linebreaks for readability.

# %%
# tickers is now a dataframe - we will iterate through
# the for construct - k is the counterm row is each row of data
# every iteration - returns a specific row

# for each row - it pulls the ticker, prints it and then takes the historical price

# we get a list, each element = one dataframe
# at the end, pd.concat is merge all the data frames together
# merges them ontop of each other - columnar

# %%
# List to hold final results
px_list = list()

for k, row in tickers.iterrows():  # Produces an iterator that returns index and row

    stock = yf.Ticker(row['ticker'])
    print(f'Processing {row["ticker"]}')
    
    px = (stock
          .history(start = pd.to_datetime("2013-12-01"), 
                   end = pd.to_datetime("2024-02-01"))
          .reset_index()   # Reset index to get date as a column
          .assign(ticker = row['ticker']))    # Add ticker
    
    if px.shape[0] == 0:
        print(f'No data for {row["ticker"]}')  # Validate: do not fail silently.
        continue
    print(f'Downloaded {px.shape}.')
    px_list.append(px)
px_dt = pd.concat(px_list, axis = 0) # merges all the dataframes together
print(f'Final shape {px_dt.shape}.')
# Out:
# Processing JCI
# Downloaded (2558, 9).
# Processing BSX
# Downloaded (2558, 9).
# Processing LIN
# Downloaded (2558, 9).
# Processing DOW
# Downloaded (1226, 9).
# Processing CVX
# Downloaded (2558, 9).
# Processing KHC
# Downloaded (2159, 9).
# Processing RL
# Downloaded (2558, 9).
# Processing ED
# Downloaded (2558, 9).
# Processing BX
# Downloaded (2558, 9).
# Processing IBM
# Downloaded (2558, 9).
# Processing A
# Downloaded (2558, 9).
# Processing FIS
# Downloaded (2558, 9).
# Processing MAS
# Downloaded (2558, 9).
# Processing CPB
# Downloaded (2558, 9).
# Processing PNW
# Downloaded (2558, 9).
# Processing QCOM
# Downloaded (2558, 9).
# Processing YUM
# Downloaded (2558, 9).
# Processing AWK
# Downloaded (2558, 9).
# Processing MU
# Downloaded (2558, 9).
# Processing RCL
# Downloaded (2558, 9).
# Processing WTW
# Downloaded (2558, 9).
# Processing GWW
# Downloaded (2558, 9).
# Processing HAS
# Downloaded (2558, 9).
# Processing PEAK
# $PEAK: possibly delisted; No timezone found
# No data for PEAK
# Processing BR
# Downloaded (2558, 9).
# Processing VLO
# Downloaded (2558, 9).
# Processing VICI
# Downloaded (1530, 9).
# Processing RHI
# Downloaded (2558, 9).
# Processing CRL
# Downloaded (2558, 9).
# Processing NEM
# Downloaded (2558, 9).
# Processing LYB
# Downloaded (2558, 9).
# Processing GS
# Downloaded (2558, 9).
# Processing V
# Downloaded (2558, 9).
# Processing EPAM
# Downloaded (2558, 9).
# Processing ABT
# Downloaded (2558, 9).
# Processing NFLX
# Downloaded (2558, 9).
# Processing KVUE
# Downloaded (187, 9).
# Processing BKNG
# Downloaded (2558, 9).
# Processing IT
# Downloaded (2558, 9).
# Processing BBY
# Downloaded (2558, 9).
# Processing NUE
# Downloaded (2558, 9).
# Processing CBRE
# Downloaded (2558, 9).
# Processing WDC
# Downloaded (2558, 9).
# Processing EXPE
# Downloaded (2558, 9).
# Processing AMGN
# Downloaded (2558, 9).
# Processing BRO
# Downloaded (2558, 9).
# Processing MMM
# Downloaded (2558, 9).
# Processing ABNB
# Downloaded (789, 9).
# Processing MDT
# Downloaded (2558, 9).
# Processing AMZN
# Downloaded (2558, 9).
# Final shape (118443, 9).

# %% [markdown]
# ## Reliability
#
# + Keppelman (2017) defines *reliability* as:
#
#     - A system should continue to work correctly.
#     - To work correctly means performing the correct function at the desired level of performance, even in the face of adversity such as hardware or software faults, and even human error.
#
# + *Faults* are things that can go wrong.
# + Sytems that can cope with (certain types of) faults are called *fault-tolerant* or *resilient*.
# + A fault is different than a failure.
#
#     - A *fault* occurs when a component of the system deviates from spec.
#     - A *failure*  is when the system stops providing the required service to the user.
#
# + In our simple example, we handle the fault that occurs when one ticker is not found and log it using *warning*.

# %% [markdown]
# # Storing Data in CSV

# %% [markdown]
# + We have some data. How do we store it?
# + We can compare two options, CSV and Parqruet, by measuring their performance:
#
#     - Time to save.
#     - Space required.

# %%
def get_dir_size(path='.'):
    '''Returns the total size of files contained in path.'''
    total = 0
    with os.scandir(path) as it:
        for entry in it:
            if entry.is_file():
                total += entry.stat().st_size
            elif entry.is_dir():
                total += get_dir_size(entry.path)
    return total

# %%
import time
# want to time execution of code

# %%
temp = os.getenv("TEMP_DATA") # just a temporary field
os.makedirs(temp, exist_ok=True) #exist)ok goes to file, and will create the filepath if it does not exist
stock_path = os.path.join(temp, "stock_px.csv") # os.path.join, will join the paths regardless of os

# %%
start = time.time()
px_dt.to_csv(stock_path, index = False)
end = time.time()

print(f'Writing to dt ({px_dt.shape})csv took {end - start} seconds.')
print(f'Csv file size { os.path.getsize(stock_path)*1e-6 } MB')
# tells us we are writing with this shape
# shows teh time and data storage required
# Out:
# Writing to dt ((118443, 9))csv took 7.973435878753662 seconds.
# Csv file size 14.155144 MB

# %% [markdown]
# ## Save Data to Parquet
#
# ### Dask
#
# We can work with with large data sets and parquet files. In fact, recent versions of pandas support pyarrow data types and future versions will require a pyarrow backend. The pyarrow library is an interface between Python and the Appache Arrow project. The [parquet data format](https://parquet.apache.org/) and [Arrow](https://arrow.apache.org/docs/python/parquet.html) are projects of the Apache Foundation.
#
# However, Dask is much more than an interface to Arrow: Dask provides parallel and distributed computing on pandas-like dataframes. It is also relatively easy to use, bridging a gap between pandas and Spark.

# %%
# like pandas
# important bit is dask to complete a dataframe
# create a path and write to a parquet file

# %%
import dask.dataframe as dd
# Out:
# c:\Users\Alexander\miniconda3\envs\dsi_participant\lib\site-packages\dask\dataframe\_pyarrow_compat.py:17: FutureWarning: Minimal version of pyarrow will soon be increased to 14.0.1. You are using 11.0.0. Please consider upgrading.
#   warnings.warn(
# C:\Users\Alexander\AppData\Local\Temp\ipykernel_5400\676544213.py:1: DeprecationWarning: The current Dask DataFrame implementation is deprecated.
# In a future release, Dask DataFrame will use new implementation that
# contains several improvements including a logical query planning.
# The user-facing DataFrame API will remain unchanged.
#
# The new implementation is already available and can be enabled by
# installing the dask-expr library:
#
#     $ pip install dask-expr
#
# and turning the query planning option on:
#
#     >>> import dask
#     >>> dask.config.set({'dataframe.query-planning': True})
#     >>> import dask.dataframe as dd
#
# API documentation for the new implementation is available at
# https://docs.dask.org/en/stable/dask-expr-api.html
#
# Any feedback can be reported on the Dask issue tracker
# https://github.com/dask/dask/issues
#
#   import dask.dataframe as dd

# %%
px_dd = dd.from_pandas(px_dt, npartitions = len(tickers))
parquet_path = os.path.join(temp, "stock_px.parquet")

start = time.time()
px_dd.to_parquet(parquet_path, engine = "pyarrow")
end = time.time()

print(f'Writing dd ({px_dt.shape}) to parquet took {end - start} seconds.')
print(f'Parquet file size { get_dir_size(parquet_path)*1e-6 } MB')
# Out:
# Writing dd ((118443, 9)) to parquet took 2.23783278465271 seconds.
# Parquet file size 5.562247 MB

# %% [markdown]
# ### Parquet files and Dask Dataframes
#
# + Parquet files are immutable: once written, they cannot be modified.
# + Dask DataFrames are a useful implementation to manipulate data stored in parquets.
# + Parquet and Dask are not the same: parquet is a file format that can be accessed by many applications and programming languages (Python, R, PowerBI, etc.), while Dask is a package in Python to work with large datasets using distributed computation.
# + **Dask is not for everything** (see [Dask DataFrames Best Practices](https://docs.dask.org/en/stable/dataframe-best-practices.html)).
#
#     - Consider cases suchas small to larrge joins, where the small dataframe fits in memory, but the large one does not.
#     - If possible, use pandas: reduce, then use pandas.
#     - Pandas performance tips apply to Dask.
#     - Use the index: it is beneficial to have a well-defined index in Dask DataFrames, as it may speed up searching (filtering) the data. A one-dimensional index is allowed.
#     - Avoid (or minimize) full-data shuffling: indexing is an expensive operations.
#     - Some joins are more expensive than others.
#
#         * Not expensive:
#
#             - Join a Dask DataFrame with a pandas DataFrame.
#             - Join a Dask DataFrame with another Dask DataFrame of a single partition.
#             - Join Dask DataFrames along their indexes.
#
#         * Expensive:
#
#             - Join Dask DataFrames along columns that are not their index.

# %% [markdown]
# # How do we store prices?
#
# + We can store our data as a single blob. This can be difficult to maintain, especially because parquet files are immutable.
# + Strategy: organize data files by ticker and date. Update only latest month.

# %%
# CLean up before start
PRICE_DATA = os.getenv("PRICE_DATA")
import shutil
if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)

# %%
for ticker in px_dt.ticker.unique(): # for every ticker, will create a subset of data, and putting it into df ticker_dt
    ticker_dt = px_dt[px_dt.ticker == ticker]
    ticker_dt = ticker_dt.assign(year = ticker_dt.Date.dt.year) #assign a new variable, the year the data was created
    for yr in ticker_dt.year.unique(): # in each year, then subset again
        yr_dt = ticker_dt[ticker_dt.year == yr]
        yr_path = os.path.join(PRICE_DATA, ticker, f"{ticker}_{yr}.parquet")
        os.makedirs(os.path.dirname(yr_path), exist_ok=True)
        yr_dt.to_parquet(yr_path, engine = "pyarrow")
    
# go to data and prices under 05_src
# in each subfolder, there are structural breakdown, data for each year and each stock

# %% [markdown]
# Why would we want to store data this way?
#
# + Easier to maintain. We do not update old data, only recent data.
# + We can also access all files as follows.

# %% [markdown]
# # Load, Transform and Save

# %% [markdown]
# ## Load
#
# + Parquet files can be read individually or as a collection.
# + `dd.read_parquet()` can take a list (collection) of files as input.
# + Use `glob` to get the collection of files.

# %%
from glob import glob

parquet_files = glob(os.path.join(PRICE_DATA, "*/*.parquet"))
dd_px = dd.read_parquet(parquet_files).set_index("ticker")
# this returns all the files that meet the indication glob

# %%
# df is empty, because dask is 'lazy'
# operating, will not opreate tasks until we need the actual code to run
# compute returns a data frame
# but the one from earlier was a dask dataframe - it was the lazy, there is no visual, just an operational db

# %% [markdown]
# ## Transform
#
# + This transformation step will create a *Features* data set. In our case, features will be stock returns (we obtained prices).
# + Dask dataframes work like pandas dataframes: in particular, we can perform groupby and apply operations.
# + Notice the use of [an anonymous (lambda) function](https://realpython.com/python-lambda/) in the apply statement.

# %%
import numpy as np
dd_rets = (dd_px.groupby('ticker', group_keys=False).apply( # dd_px is the dataframe with all the rows
    lambda x: x.assign(Close_lag_1 = x['Close'].shift(1)) #index is a grouping variable, dask is the most efficient grouper, lambda is an anonymous function created on the fly
).assign(
    returns = lambda x: x['Close']/x['Close_lag_1'] - 1
).assign(
    positive_return = lambda x: (x['returns'] > 0)*1
))
# Out:
# C:\Users\Alexander\AppData\Local\Temp\ipykernel_5400\3091835559.py:2: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   dd_rets = (dd_px.groupby('ticker', group_keys=False).apply(

# %% [markdown]
# ## Lazy Exection
#
# What does `dd_rets` contain?

# %%
dd_rets
# Out:
# Dask DataFrame Structure:
#                                             Date     Open     High      Low    Close Volume Dividends Stock Splits   year Close_lag_1  returns positive_return
# npartitions=49
# A               datetime64[ns, America/New_York]  float64  float64  float64  float64  int64   float64      float64  int32     float64  float64           int32
# ABNB                                         ...      ...      ...      ...      ...    ...       ...          ...    ...         ...      ...             ...
# ...                                          ...      ...      ...      ...      ...    ...       ...          ...    ...         ...      ...             ...
# YUM                                          ...      ...      ...      ...      ...    ...       ...          ...    ...         ...      ...             ...
# YUM                                          ...      ...      ...      ...      ...    ...       ...          ...    ...         ...      ...             ...
# Dask Name: assign, 18 graph layers

# %% [markdown]
# + Dask is a lazy execution framework: commands will not execute until they are required.
# + To trigger an execution in dask use `.compute()`.

# %%
dd_rets.compute()
# will then return the orignal dataframe, and the new columns with returns
# ad the positive return flag
# report numpy - run mathematical functions faster

## dd is a common naming conventions for dask dataframes
# Out:
#                             Date        Open        High         Low  \
# ticker
# A      2024-01-02 00:00:00-05:00  137.491402  139.879263  137.212819
# A      2024-01-03 00:00:00-05:00  137.302382  137.302382  130.407422
# A      2024-01-04 00:00:00-05:00  129.890046  130.835241  129.531866
# A      2024-01-05 00:00:00-05:00  129.342812  131.292910  127.969783
# A      2024-01-08 00:00:00-05:00  129.482108  132.894776  129.153774
# ...                          ...         ...         ...         ...
# YUM    2024-01-25 00:00:00-05:00  127.913548  128.386458  126.642582
# YUM    2024-01-26 00:00:00-05:00  128.002206  128.760844  126.770657
# YUM    2024-01-29 00:00:00-05:00  127.194317  128.622910  126.396261
# YUM    2024-01-30 00:00:00-05:00  128.435723  129.283029  127.667238
# YUM    2024-01-31 00:00:00-05:00  129.509619  130.031795  127.351944
#
#              Close   Volume  Dividends  Stock Splits  year  Close_lag_1  \
# ticker
# A       138.048569  1441600        0.0           0.0  2024          NaN
# A       130.496964  2074500        0.0           0.0  2024   138.048569
# A       130.337769  2446600        0.0           0.0  2024   130.496964
# A       129.899979  1394000        0.0           0.0  2024   130.337769
# A       132.705734  1311400        0.0           0.0  2024   129.899979
# ...            ...      ...        ...           ...   ...          ...
# YUM     128.297791  1871700        0.0           0.0  2024   127.529289
# YUM     127.184456  1157000        0.0           0.0  2024   128.297791
# YUM     128.622910  1482100        0.0           0.0  2024   127.184456
# YUM     128.691879  1421500        0.0           0.0  2024   128.622910
# YUM     127.578560  2154200        0.0           0.0  2024   128.691879
#
#          returns  positive_return
# ticker
# A            NaN                0
# A      -0.054703                0
# A      -0.001220                0
# A      -0.003359                0
# A       0.021599                1
# ...          ...              ...
# YUM     0.006026                1
# YUM    -0.008678                0
# YUM     0.011310                1
# YUM     0.000536                1
# YUM    -0.008651                0
#
# [118443 rows x 12 columns]

# %% [markdown]
# ## Save
#
# + Apply transformations to calculate daily returns
# + Store the enriched data, the silver dataset, in a new directory.
# + Should we keep the same namespace? All columns?

# %%
# CLean up before start
FEATURES_DATA = os.getenv("FEATURES_DATA")
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)

# %%
FEATURES_DATA = os.getenv("FEATURES_DATA")
dd_rets.to_parquet(FEATURES_DATA, engine = "pyarrow")

# %% [markdown]
# # A few notes
#
# # Jupyter?
#
# + We have drafted our code in a Jupyter Notebook.
# + Finalized code should be written in Python modules.
#
# ## Object oriented programming?
#
# + We can use classes to keep parameters and functions together.
# + We *could* use Object Oriented Programming, but parallelization of data manipulation and modelling tasks benefits from *Functional Programming*.
# + An Idea:
#
#     - [Data Oriented Programming](https://blog.klipse.tech/dop/2022/06/22/principles-of-dop.html).
#     - Use the class to bundle together parameters and functions.
#     - Use stateless operations and treat all data objects as immutable (we do not modify them, we overwrite them).
#     - Take advantage of [`@staticmethod`](https://realpython.com/instance-class-and-static-methods-demystified/).
#
# The code is in `./05_src/`.

# %% [markdown]
# Our original design was:
#
# ![](./images/02_target_pipeline_manager.png)

# %% [markdown]
# Below, we demonstrate how our class implementation works.
#
# Before we begin, clean the price directory (we will download everything again).

# %%
# CLean up before start

if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)

# %% [markdown]
# Now, instantiate a DataManager object and download all the data.

# %%
from data_manager import DataManager
dm = DataManager()

# %%
dm.download_all()
# Out:
# 2024-10-23 20:43:50,234, data_manager.py, 43, INFO, Getting price data for all tickers.
# 2024-10-23 20:43:50,234, data_manager.py, 43, INFO, Getting price data for all tickers.
# 2024-10-23 20:43:50,236, data_manager.py, 52, INFO, Getting tickers from ../../05_src/data/tickers/sp500_wiki.csv
# 2024-10-23 20:43:50,236, data_manager.py, 52, INFO, Getting tickers from ../../05_src/data/tickers/sp500_wiki.csv
# 2024-10-23 20:43:50,256, data_manager.py, 58, INFO, Processing all tickers
# 2024-10-23 20:43:50,256, data_manager.py, 58, INFO, Processing all tickers
# 2024-10-23 20:43:50,260, data_manager.py, 73, INFO, Processing ticker MMM
# 2024-10-23 20:43:50,260, data_manager.py, 73, INFO, Processing ticker MMM
# 2024-10-23 20:43:50,264, data_manager.py, 109, INFO, Getting stock price data for MMM from 2000-01-01 to 2024-10-23
# 2024-10-23 20:43:50,264, data_manager.py, 109, INFO, Getting stock price data for MMM from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:43:51,002, data_manager.py, 83, INFO, Saving data for MMM by year
# 2024-10-23 20:43:51,002, data_manager.py, 83, INFO, Saving data for MMM by year
# 2024-10-23 20:43:53,711, data_manager.py, 73, INFO, Processing ticker AOS
# 2024-10-23 20:43:53,711, data_manager.py, 73, INFO, Processing ticker AOS
# 2024-10-23 20:43:53,716, data_manager.py, 109, INFO, Getting stock price data for AOS from 2000-01-01 to 2024-10-23
# 2024-10-23 20:43:53,716, data_manager.py, 109, INFO, Getting stock price data for AOS from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:43:54,353, data_manager.py, 83, INFO, Saving data for AOS by year
# 2024-10-23 20:43:54,353, data_manager.py, 83, INFO, Saving data for AOS by year
# 2024-10-23 20:43:56,632, data_manager.py, 73, INFO, Processing ticker ABT
# 2024-10-23 20:43:56,632, data_manager.py, 73, INFO, Processing ticker ABT
# 2024-10-23 20:43:56,636, data_manager.py, 109, INFO, Getting stock price data for ABT from 2000-01-01 to 2024-10-23
# 2024-10-23 20:43:56,636, data_manager.py, 109, INFO, Getting stock price data for ABT from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:43:57,273, data_manager.py, 83, INFO, Saving data for ABT by year
# 2024-10-23 20:43:57,273, data_manager.py, 83, INFO, Saving data for ABT by year
# 2024-10-23 20:43:59,703, data_manager.py, 73, INFO, Processing ticker ABBV
# 2024-10-23 20:43:59,703, data_manager.py, 73, INFO, Processing ticker ABBV
# 2024-10-23 20:43:59,706, data_manager.py, 109, INFO, Getting stock price data for ABBV from 2000-01-01 to 2024-10-23
# 2024-10-23 20:43:59,706, data_manager.py, 109, INFO, Getting stock price data for ABBV from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:44:00,143, data_manager.py, 83, INFO, Saving data for ABBV by year
# 2024-10-23 20:44:00,143, data_manager.py, 83, INFO, Saving data for ABBV by year
# 2024-10-23 20:44:01,379, data_manager.py, 73, INFO, Processing ticker ACN
# 2024-10-23 20:44:01,379, data_manager.py, 73, INFO, Processing ticker ACN
# 2024-10-23 20:44:01,382, data_manager.py, 109, INFO, Getting stock price data for ACN from 2000-01-01 to 2024-10-23
# 2024-10-23 20:44:01,382, data_manager.py, 109, INFO, Getting stock price data for ACN from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:44:01,949, data_manager.py, 83, INFO, Saving data for ACN by year
# 2024-10-23 20:44:01,949, data_manager.py, 83, INFO, Saving data for ACN by year
# 2024-10-23 20:44:04,171, data_manager.py, 73, INFO, Processing ticker ADBE
# 2024-10-23 20:44:04,171, data_manager.py, 73, INFO, Processing ticker ADBE
# 2024-10-23 20:44:04,174, data_manager.py, 109, INFO, Getting stock price data for ADBE from 2000-01-01 to 2024-10-23
# 2024-10-23 20:44:04,174, data_manager.py, 109, INFO, Getting stock price data for ADBE from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:44:04,706, data_manager.py, 83, INFO, Saving data for ADBE by year
# 2024-10-23 20:44:04,706, data_manager.py, 83, INFO, Saving data for ADBE by year
# 2024-10-23 20:44:07,273, data_manager.py, 73, INFO, Processing ticker AMD
# 2024-10-23 20:44:07,273, data_manager.py, 73, INFO, Processing ticker AMD
# 2024-10-23 20:44:07,276, data_manager.py, 109, INFO, Getting stock price data for AMD from 2000-01-01 to 2024-10-23
# 2024-10-23 20:44:07,276, data_manager.py, 109, INFO, Getting stock price data for AMD from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:44:07,737, data_manager.py, 83, INFO, Saving data for AMD by year
# 2024-10-23 20:44:07,737, data_manager.py, 83, INFO, Saving data for AMD by year
# 2024-10-23 20:44:10,209, data_manager.py, 73, INFO, Processing ticker AES
# 2024-10-23 20:44:10,209, data_manager.py, 73, INFO, Processing ticker AES
# 2024-10-23 20:44:10,212, data_manager.py, 109, INFO, Getting stock price data for AES from 2000-01-01 to 2024-10-23
# 2024-10-23 20:44:10,212, data_manager.py, 109, INFO, Getting stock price data for AES from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:44:10,806, data_manager.py, 83, INFO, Saving data for AES by year
# 2024-10-23 20:44:10,806, data_manager.py, 83, INFO, Saving data for AES by year
# 2024-10-23 20:44:13,230, data_manager.py, 73, INFO, Processing ticker AFL
# 2024-10-23 20:44:13,230, data_manager.py, 73, INFO, Processing ticker AFL
# 2024-10-23 20:44:13,232, data_manager.py, 109, INFO, Getting stock price data for AFL from 2000-01-01 to 2024-10-23
# 2024-10-23 20:44:13,232, data_manager.py, 109, INFO, Getting stock price data for AFL from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:44:13,874, data_manager.py, 83, INFO, Saving data for AFL by year
# 2024-10-23 20:44:13,874, data_manager.py, 83, INFO, Saving data for AFL by year
# 2024-10-23 20:44:16,303, data_manager.py, 73, INFO, Processing ticker A
# 2024-10-23 20:44:16,303, data_manager.py, 73, INFO, Processing ticker A
# 2024-10-23 20:44:16,306, data_manager.py, 109, INFO, Getting stock price data for A from 2000-01-01 to 2024-10-23
# 2024-10-23 20:44:16,306, data_manager.py, 109, INFO, Getting stock price data for A from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:44:16,891, data_manager.py, 83, INFO, Saving data for A by year
# 2024-10-23 20:44:16,891, data_manager.py, 83, INFO, Saving data for A by year
# 2024-10-23 20:44:19,697, data_manager.py, 73, INFO, Processing ticker APD
# 2024-10-23 20:44:19,697, data_manager.py, 73, INFO, Processing ticker APD
# 2024-10-23 20:44:19,701, data_manager.py, 109, INFO, Getting stock price data for APD from 2000-01-01 to 2024-10-23
# 2024-10-23 20:44:19,701, data_manager.py, 109, INFO, Getting stock price data for APD from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:44:20,384, data_manager.py, 83, INFO, Saving data for APD by year
# 2024-10-23 20:44:20,384, data_manager.py, 83, INFO, Saving data for APD by year
# 2024-10-23 20:44:23,079, data_manager.py, 73, INFO, Processing ticker ABNB
# 2024-10-23 20:44:23,079, data_manager.py, 73, INFO, Processing ticker ABNB
# 2024-10-23 20:44:23,081, data_manager.py, 109, INFO, Getting stock price data for ABNB from 2000-01-01 to 2024-10-23
# 2024-10-23 20:44:23,081, data_manager.py, 109, INFO, Getting stock price data for ABNB from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:44:23,308, data_manager.py, 83, INFO, Saving data for ABNB by year
# 2024-10-23 20:44:23,308, data_manager.py, 83, INFO, Saving data for ABNB by year
# 2024-10-23 20:44:23,883, data_manager.py, 73, INFO, Processing ticker AKAM
# 2024-10-23 20:44:23,883, data_manager.py, 73, INFO, Processing ticker AKAM
# 2024-10-23 20:44:23,893, data_manager.py, 109, INFO, Getting stock price data for AKAM from 2000-01-01 to 2024-10-23
# 2024-10-23 20:44:23,893, data_manager.py, 109, INFO, Getting stock price data for AKAM from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:44:24,368, data_manager.py, 83, INFO, Saving data for AKAM by year
# 2024-10-23 20:44:24,368, data_manager.py, 83, INFO, Saving data for AKAM by year
# 2024-10-23 20:44:26,997, data_manager.py, 73, INFO, Processing ticker ALB
# 2024-10-23 20:44:26,997, data_manager.py, 73, INFO, Processing ticker ALB
# 2024-10-23 20:44:27,001, data_manager.py, 109, INFO, Getting stock price data for ALB from 2000-01-01 to 2024-10-23
# 2024-10-23 20:44:27,001, data_manager.py, 109, INFO, Getting stock price data for ALB from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:44:27,645, data_manager.py, 83, INFO, Saving data for ALB by year
# 2024-10-23 20:44:27,645, data_manager.py, 83, INFO, Saving data for ALB by year
# 2024-10-23 20:44:30,162, data_manager.py, 73, INFO, Processing ticker ARE
# 2024-10-23 20:44:30,162, data_manager.py, 73, INFO, Processing ticker ARE
# 2024-10-23 20:44:30,165, data_manager.py, 109, INFO, Getting stock price data for ARE from 2000-01-01 to 2024-10-23
# 2024-10-23 20:44:30,165, data_manager.py, 109, INFO, Getting stock price data for ARE from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:44:30,771, data_manager.py, 83, INFO, Saving data for ARE by year
# 2024-10-23 20:44:30,771, data_manager.py, 83, INFO, Saving data for ARE by year
# 2024-10-23 20:44:33,198, data_manager.py, 73, INFO, Processing ticker ALGN
# 2024-10-23 20:44:33,198, data_manager.py, 73, INFO, Processing ticker ALGN
# 2024-10-23 20:44:33,210, data_manager.py, 109, INFO, Getting stock price data for ALGN from 2000-01-01 to 2024-10-23
# 2024-10-23 20:44:33,210, data_manager.py, 109, INFO, Getting stock price data for ALGN from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:44:33,655, data_manager.py, 83, INFO, Saving data for ALGN by year
# 2024-10-23 20:44:33,655, data_manager.py, 83, INFO, Saving data for ALGN by year
# 2024-10-23 20:44:36,017, data_manager.py, 73, INFO, Processing ticker ALLE
# 2024-10-23 20:44:36,017, data_manager.py, 73, INFO, Processing ticker ALLE
# 2024-10-23 20:44:36,020, data_manager.py, 109, INFO, Getting stock price data for ALLE from 2000-01-01 to 2024-10-23
# 2024-10-23 20:44:36,020, data_manager.py, 109, INFO, Getting stock price data for ALLE from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:44:36,429, data_manager.py, 83, INFO, Saving data for ALLE by year
# 2024-10-23 20:44:36,429, data_manager.py, 83, INFO, Saving data for ALLE by year
# 2024-10-23 20:44:38,731, data_manager.py, 73, INFO, Processing ticker LNT
# 2024-10-23 20:44:38,731, data_manager.py, 73, INFO, Processing ticker LNT
# 2024-10-23 20:44:38,735, data_manager.py, 109, INFO, Getting stock price data for LNT from 2000-01-01 to 2024-10-23
# 2024-10-23 20:44:38,735, data_manager.py, 109, INFO, Getting stock price data for LNT from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:44:39,372, data_manager.py, 83, INFO, Saving data for LNT by year
# 2024-10-23 20:44:39,372, data_manager.py, 83, INFO, Saving data for LNT by year
# 2024-10-23 20:44:42,277, data_manager.py, 73, INFO, Processing ticker ALL
# 2024-10-23 20:44:42,277, data_manager.py, 73, INFO, Processing ticker ALL
# 2024-10-23 20:44:42,280, data_manager.py, 109, INFO, Getting stock price data for ALL from 2000-01-01 to 2024-10-23
# 2024-10-23 20:44:42,280, data_manager.py, 109, INFO, Getting stock price data for ALL from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:44:42,866, data_manager.py, 83, INFO, Saving data for ALL by year
# 2024-10-23 20:44:42,866, data_manager.py, 83, INFO, Saving data for ALL by year
# 2024-10-23 20:44:45,428, data_manager.py, 73, INFO, Processing ticker GOOGL
# 2024-10-23 20:44:45,428, data_manager.py, 73, INFO, Processing ticker GOOGL
# 2024-10-23 20:44:45,430, data_manager.py, 109, INFO, Getting stock price data for GOOGL from 2000-01-01 to 2024-10-23
# 2024-10-23 20:44:45,430, data_manager.py, 109, INFO, Getting stock price data for GOOGL from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:44:45,989, data_manager.py, 83, INFO, Saving data for GOOGL by year
# 2024-10-23 20:44:45,989, data_manager.py, 83, INFO, Saving data for GOOGL by year
# 2024-10-23 20:44:47,837, data_manager.py, 73, INFO, Processing ticker GOOG
# 2024-10-23 20:44:47,837, data_manager.py, 73, INFO, Processing ticker GOOG
# 2024-10-23 20:44:47,839, data_manager.py, 109, INFO, Getting stock price data for GOOG from 2000-01-01 to 2024-10-23
# 2024-10-23 20:44:47,839, data_manager.py, 109, INFO, Getting stock price data for GOOG from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:44:48,462, data_manager.py, 83, INFO, Saving data for GOOG by year
# 2024-10-23 20:44:48,462, data_manager.py, 83, INFO, Saving data for GOOG by year
# 2024-10-23 20:44:50,705, data_manager.py, 73, INFO, Processing ticker MO
# 2024-10-23 20:44:50,705, data_manager.py, 73, INFO, Processing ticker MO
# 2024-10-23 20:44:50,708, data_manager.py, 109, INFO, Getting stock price data for MO from 2000-01-01 to 2024-10-23
# 2024-10-23 20:44:50,708, data_manager.py, 109, INFO, Getting stock price data for MO from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:44:51,525, data_manager.py, 83, INFO, Saving data for MO by year
# 2024-10-23 20:44:51,525, data_manager.py, 83, INFO, Saving data for MO by year
# 2024-10-23 20:44:56,302, data_manager.py, 73, INFO, Processing ticker AMZN
# 2024-10-23 20:44:56,302, data_manager.py, 73, INFO, Processing ticker AMZN
# 2024-10-23 20:44:56,309, data_manager.py, 109, INFO, Getting stock price data for AMZN from 2000-01-01 to 2024-10-23
# 2024-10-23 20:44:56,309, data_manager.py, 109, INFO, Getting stock price data for AMZN from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:44:56,801, data_manager.py, 83, INFO, Saving data for AMZN by year
# 2024-10-23 20:44:56,801, data_manager.py, 83, INFO, Saving data for AMZN by year
# 2024-10-23 20:44:59,606, data_manager.py, 73, INFO, Processing ticker AMCR
# 2024-10-23 20:44:59,606, data_manager.py, 73, INFO, Processing ticker AMCR
# 2024-10-23 20:44:59,608, data_manager.py, 109, INFO, Getting stock price data for AMCR from 2000-01-01 to 2024-10-23
# 2024-10-23 20:44:59,608, data_manager.py, 109, INFO, Getting stock price data for AMCR from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:45:00,117, data_manager.py, 83, INFO, Saving data for AMCR by year
# 2024-10-23 20:45:00,117, data_manager.py, 83, INFO, Saving data for AMCR by year
# 2024-10-23 20:45:02,109, data_manager.py, 73, INFO, Processing ticker AEE
# 2024-10-23 20:45:02,109, data_manager.py, 73, INFO, Processing ticker AEE
# 2024-10-23 20:45:02,112, data_manager.py, 109, INFO, Getting stock price data for AEE from 2000-01-01 to 2024-10-23
# 2024-10-23 20:45:02,112, data_manager.py, 109, INFO, Getting stock price data for AEE from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:45:02,830, data_manager.py, 83, INFO, Saving data for AEE by year
# 2024-10-23 20:45:02,830, data_manager.py, 83, INFO, Saving data for AEE by year
# 2024-10-23 20:45:05,689, data_manager.py, 73, INFO, Processing ticker AAL
# 2024-10-23 20:45:05,689, data_manager.py, 73, INFO, Processing ticker AAL
# 2024-10-23 20:45:05,692, data_manager.py, 109, INFO, Getting stock price data for AAL from 2000-01-01 to 2024-10-23
# 2024-10-23 20:45:05,692, data_manager.py, 109, INFO, Getting stock price data for AAL from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:45:06,220, data_manager.py, 83, INFO, Saving data for AAL by year
# 2024-10-23 20:45:06,220, data_manager.py, 83, INFO, Saving data for AAL by year
# 2024-10-23 20:45:08,613, data_manager.py, 73, INFO, Processing ticker AEP
# 2024-10-23 20:45:08,613, data_manager.py, 73, INFO, Processing ticker AEP
# 2024-10-23 20:45:08,631, data_manager.py, 109, INFO, Getting stock price data for AEP from 2000-01-01 to 2024-10-23
# 2024-10-23 20:45:08,631, data_manager.py, 109, INFO, Getting stock price data for AEP from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:45:09,391, data_manager.py, 83, INFO, Saving data for AEP by year
# 2024-10-23 20:45:09,391, data_manager.py, 83, INFO, Saving data for AEP by year
# 2024-10-23 20:45:13,079, data_manager.py, 73, INFO, Processing ticker AXP
# 2024-10-23 20:45:13,079, data_manager.py, 73, INFO, Processing ticker AXP
# 2024-10-23 20:45:13,082, data_manager.py, 109, INFO, Getting stock price data for AXP from 2000-01-01 to 2024-10-23
# 2024-10-23 20:45:13,082, data_manager.py, 109, INFO, Getting stock price data for AXP from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:45:13,931, data_manager.py, 83, INFO, Saving data for AXP by year
# 2024-10-23 20:45:13,931, data_manager.py, 83, INFO, Saving data for AXP by year
# 2024-10-23 20:45:16,607, data_manager.py, 73, INFO, Processing ticker AIG
# 2024-10-23 20:45:16,607, data_manager.py, 73, INFO, Processing ticker AIG
# 2024-10-23 20:45:16,611, data_manager.py, 109, INFO, Getting stock price data for AIG from 2000-01-01 to 2024-10-23
# 2024-10-23 20:45:16,611, data_manager.py, 109, INFO, Getting stock price data for AIG from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:45:17,503, data_manager.py, 83, INFO, Saving data for AIG by year
# 2024-10-23 20:45:17,503, data_manager.py, 83, INFO, Saving data for AIG by year
# 2024-10-23 20:45:20,406, data_manager.py, 73, INFO, Processing ticker AMT
# 2024-10-23 20:45:20,406, data_manager.py, 73, INFO, Processing ticker AMT
# 2024-10-23 20:45:20,410, data_manager.py, 109, INFO, Getting stock price data for AMT from 2000-01-01 to 2024-10-23
# 2024-10-23 20:45:20,410, data_manager.py, 109, INFO, Getting stock price data for AMT from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:45:20,972, data_manager.py, 83, INFO, Saving data for AMT by year
# 2024-10-23 20:45:20,972, data_manager.py, 83, INFO, Saving data for AMT by year
# 2024-10-23 20:45:23,930, data_manager.py, 73, INFO, Processing ticker AWK
# 2024-10-23 20:45:23,930, data_manager.py, 73, INFO, Processing ticker AWK
# 2024-10-23 20:45:23,938, data_manager.py, 109, INFO, Getting stock price data for AWK from 2000-01-01 to 2024-10-23
# 2024-10-23 20:45:23,938, data_manager.py, 109, INFO, Getting stock price data for AWK from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:45:24,725, data_manager.py, 83, INFO, Saving data for AWK by year
# 2024-10-23 20:45:24,725, data_manager.py, 83, INFO, Saving data for AWK by year
# 2024-10-23 20:45:27,019, data_manager.py, 73, INFO, Processing ticker AMP
# 2024-10-23 20:45:27,019, data_manager.py, 73, INFO, Processing ticker AMP
# 2024-10-23 20:45:27,023, data_manager.py, 109, INFO, Getting stock price data for AMP from 2000-01-01 to 2024-10-23
# 2024-10-23 20:45:27,023, data_manager.py, 109, INFO, Getting stock price data for AMP from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:45:27,572, data_manager.py, 83, INFO, Saving data for AMP by year
# 2024-10-23 20:45:27,572, data_manager.py, 83, INFO, Saving data for AMP by year
# 2024-10-23 20:45:30,349, data_manager.py, 73, INFO, Processing ticker AME
# 2024-10-23 20:45:30,349, data_manager.py, 73, INFO, Processing ticker AME
# 2024-10-23 20:45:30,360, data_manager.py, 109, INFO, Getting stock price data for AME from 2000-01-01 to 2024-10-23
# 2024-10-23 20:45:30,360, data_manager.py, 109, INFO, Getting stock price data for AME from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:45:31,317, data_manager.py, 83, INFO, Saving data for AME by year
# 2024-10-23 20:45:31,317, data_manager.py, 83, INFO, Saving data for AME by year
# 2024-10-23 20:45:34,397, data_manager.py, 73, INFO, Processing ticker AMGN
# 2024-10-23 20:45:34,397, data_manager.py, 73, INFO, Processing ticker AMGN
# 2024-10-23 20:45:34,402, data_manager.py, 109, INFO, Getting stock price data for AMGN from 2000-01-01 to 2024-10-23
# 2024-10-23 20:45:34,402, data_manager.py, 109, INFO, Getting stock price data for AMGN from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:45:34,894, data_manager.py, 83, INFO, Saving data for AMGN by year
# 2024-10-23 20:45:34,894, data_manager.py, 83, INFO, Saving data for AMGN by year
# 2024-10-23 20:45:37,992, data_manager.py, 73, INFO, Processing ticker APH
# 2024-10-23 20:45:37,992, data_manager.py, 73, INFO, Processing ticker APH
# 2024-10-23 20:45:37,997, data_manager.py, 109, INFO, Getting stock price data for APH from 2000-01-01 to 2024-10-23
# 2024-10-23 20:45:37,997, data_manager.py, 109, INFO, Getting stock price data for APH from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:45:38,600, data_manager.py, 83, INFO, Saving data for APH by year
# 2024-10-23 20:45:38,600, data_manager.py, 83, INFO, Saving data for APH by year
# 2024-10-23 20:45:41,503, data_manager.py, 73, INFO, Processing ticker ADI
# 2024-10-23 20:45:41,503, data_manager.py, 73, INFO, Processing ticker ADI
# 2024-10-23 20:45:41,510, data_manager.py, 109, INFO, Getting stock price data for ADI from 2000-01-01 to 2024-10-23
# 2024-10-23 20:45:41,510, data_manager.py, 109, INFO, Getting stock price data for ADI from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:45:42,257, data_manager.py, 83, INFO, Saving data for ADI by year
# 2024-10-23 20:45:42,257, data_manager.py, 83, INFO, Saving data for ADI by year
# 2024-10-23 20:45:45,261, data_manager.py, 73, INFO, Processing ticker ANSS
# 2024-10-23 20:45:45,261, data_manager.py, 73, INFO, Processing ticker ANSS
# 2024-10-23 20:45:45,265, data_manager.py, 109, INFO, Getting stock price data for ANSS from 2000-01-01 to 2024-10-23
# 2024-10-23 20:45:45,265, data_manager.py, 109, INFO, Getting stock price data for ANSS from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:45:45,871, data_manager.py, 83, INFO, Saving data for ANSS by year
# 2024-10-23 20:45:45,871, data_manager.py, 83, INFO, Saving data for ANSS by year
# 2024-10-23 20:45:48,207, data_manager.py, 73, INFO, Processing ticker AON
# 2024-10-23 20:45:48,207, data_manager.py, 73, INFO, Processing ticker AON
# 2024-10-23 20:45:48,210, data_manager.py, 109, INFO, Getting stock price data for AON from 2000-01-01 to 2024-10-23
# 2024-10-23 20:45:48,210, data_manager.py, 109, INFO, Getting stock price data for AON from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:45:48,859, data_manager.py, 83, INFO, Saving data for AON by year
# 2024-10-23 20:45:48,859, data_manager.py, 83, INFO, Saving data for AON by year
# 2024-10-23 20:45:51,619, data_manager.py, 73, INFO, Processing ticker APA
# 2024-10-23 20:45:51,619, data_manager.py, 73, INFO, Processing ticker APA
# 2024-10-23 20:45:51,627, data_manager.py, 109, INFO, Getting stock price data for APA from 2000-01-01 to 2024-10-23
# 2024-10-23 20:45:51,627, data_manager.py, 109, INFO, Getting stock price data for APA from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:45:52,299, data_manager.py, 83, INFO, Saving data for APA by year
# 2024-10-23 20:45:52,299, data_manager.py, 83, INFO, Saving data for APA by year
# 2024-10-23 20:45:54,914, data_manager.py, 73, INFO, Processing ticker AAPL
# 2024-10-23 20:45:54,914, data_manager.py, 73, INFO, Processing ticker AAPL
# 2024-10-23 20:45:54,918, data_manager.py, 109, INFO, Getting stock price data for AAPL from 2000-01-01 to 2024-10-23
# 2024-10-23 20:45:54,918, data_manager.py, 109, INFO, Getting stock price data for AAPL from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:45:55,491, data_manager.py, 83, INFO, Saving data for AAPL by year
# 2024-10-23 20:45:55,491, data_manager.py, 83, INFO, Saving data for AAPL by year
# 2024-10-23 20:45:58,555, data_manager.py, 73, INFO, Processing ticker AMAT
# 2024-10-23 20:45:58,555, data_manager.py, 73, INFO, Processing ticker AMAT
# 2024-10-23 20:45:58,559, data_manager.py, 109, INFO, Getting stock price data for AMAT from 2000-01-01 to 2024-10-23
# 2024-10-23 20:45:58,559, data_manager.py, 109, INFO, Getting stock price data for AMAT from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:45:59,259, data_manager.py, 83, INFO, Saving data for AMAT by year
# 2024-10-23 20:45:59,259, data_manager.py, 83, INFO, Saving data for AMAT by year
# 2024-10-23 20:46:02,008, data_manager.py, 73, INFO, Processing ticker APTV
# 2024-10-23 20:46:02,008, data_manager.py, 73, INFO, Processing ticker APTV
# 2024-10-23 20:46:02,020, data_manager.py, 109, INFO, Getting stock price data for APTV from 2000-01-01 to 2024-10-23
# 2024-10-23 20:46:02,020, data_manager.py, 109, INFO, Getting stock price data for APTV from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:46:02,549, data_manager.py, 83, INFO, Saving data for APTV by year
# 2024-10-23 20:46:02,549, data_manager.py, 83, INFO, Saving data for APTV by year
# 2024-10-23 20:46:03,965, data_manager.py, 73, INFO, Processing ticker ACGL
# 2024-10-23 20:46:03,965, data_manager.py, 73, INFO, Processing ticker ACGL
# 2024-10-23 20:46:03,970, data_manager.py, 109, INFO, Getting stock price data for ACGL from 2000-01-01 to 2024-10-23
# 2024-10-23 20:46:03,970, data_manager.py, 109, INFO, Getting stock price data for ACGL from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:46:04,510, data_manager.py, 83, INFO, Saving data for ACGL by year
# 2024-10-23 20:46:04,510, data_manager.py, 83, INFO, Saving data for ACGL by year
# 2024-10-23 20:46:06,893, data_manager.py, 73, INFO, Processing ticker ADM
# 2024-10-23 20:46:06,893, data_manager.py, 73, INFO, Processing ticker ADM
# 2024-10-23 20:46:06,896, data_manager.py, 109, INFO, Getting stock price data for ADM from 2000-01-01 to 2024-10-23
# 2024-10-23 20:46:06,896, data_manager.py, 109, INFO, Getting stock price data for ADM from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:46:07,547, data_manager.py, 83, INFO, Saving data for ADM by year
# 2024-10-23 20:46:07,547, data_manager.py, 83, INFO, Saving data for ADM by year
# 2024-10-23 20:46:10,040, data_manager.py, 73, INFO, Processing ticker ANET
# 2024-10-23 20:46:10,040, data_manager.py, 73, INFO, Processing ticker ANET
# 2024-10-23 20:46:10,043, data_manager.py, 109, INFO, Getting stock price data for ANET from 2000-01-01 to 2024-10-23
# 2024-10-23 20:46:10,043, data_manager.py, 109, INFO, Getting stock price data for ANET from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:46:10,438, data_manager.py, 83, INFO, Saving data for ANET by year
# 2024-10-23 20:46:10,438, data_manager.py, 83, INFO, Saving data for ANET by year
# 2024-10-23 20:46:11,668, data_manager.py, 73, INFO, Processing ticker AJG
# 2024-10-23 20:46:11,668, data_manager.py, 73, INFO, Processing ticker AJG
# 2024-10-23 20:46:11,673, data_manager.py, 109, INFO, Getting stock price data for AJG from 2000-01-01 to 2024-10-23
# 2024-10-23 20:46:11,673, data_manager.py, 109, INFO, Getting stock price data for AJG from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:46:12,360, data_manager.py, 83, INFO, Saving data for AJG by year
# 2024-10-23 20:46:12,360, data_manager.py, 83, INFO, Saving data for AJG by year
# 2024-10-23 20:46:15,292, data_manager.py, 73, INFO, Processing ticker AIZ
# 2024-10-23 20:46:15,292, data_manager.py, 73, INFO, Processing ticker AIZ
# 2024-10-23 20:46:15,297, data_manager.py, 109, INFO, Getting stock price data for AIZ from 2000-01-01 to 2024-10-23
# 2024-10-23 20:46:15,297, data_manager.py, 109, INFO, Getting stock price data for AIZ from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:46:15,832, data_manager.py, 83, INFO, Saving data for AIZ by year
# 2024-10-23 20:46:15,832, data_manager.py, 83, INFO, Saving data for AIZ by year
# 2024-10-23 20:46:18,166, data_manager.py, 73, INFO, Processing ticker T
# 2024-10-23 20:46:18,166, data_manager.py, 73, INFO, Processing ticker T
# 2024-10-23 20:46:18,171, data_manager.py, 109, INFO, Getting stock price data for T from 2000-01-01 to 2024-10-23
# 2024-10-23 20:46:18,171, data_manager.py, 109, INFO, Getting stock price data for T from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:46:18,925, data_manager.py, 83, INFO, Saving data for T by year
# 2024-10-23 20:46:18,925, data_manager.py, 83, INFO, Saving data for T by year
# 2024-10-23 20:46:21,869, data_manager.py, 73, INFO, Processing ticker ATO
# 2024-10-23 20:46:21,869, data_manager.py, 73, INFO, Processing ticker ATO
# 2024-10-23 20:46:21,873, data_manager.py, 109, INFO, Getting stock price data for ATO from 2000-01-01 to 2024-10-23
# 2024-10-23 20:46:21,873, data_manager.py, 109, INFO, Getting stock price data for ATO from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:46:22,435, data_manager.py, 83, INFO, Saving data for ATO by year
# 2024-10-23 20:46:22,435, data_manager.py, 83, INFO, Saving data for ATO by year
# 2024-10-23 20:46:25,059, data_manager.py, 73, INFO, Processing ticker ADSK
# 2024-10-23 20:46:25,059, data_manager.py, 73, INFO, Processing ticker ADSK
# 2024-10-23 20:46:25,062, data_manager.py, 109, INFO, Getting stock price data for ADSK from 2000-01-01 to 2024-10-23
# 2024-10-23 20:46:25,062, data_manager.py, 109, INFO, Getting stock price data for ADSK from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:46:25,696, data_manager.py, 83, INFO, Saving data for ADSK by year
# 2024-10-23 20:46:25,696, data_manager.py, 83, INFO, Saving data for ADSK by year
# 2024-10-23 20:46:27,862, data_manager.py, 73, INFO, Processing ticker ADP
# 2024-10-23 20:46:27,862, data_manager.py, 73, INFO, Processing ticker ADP
# 2024-10-23 20:46:27,865, data_manager.py, 109, INFO, Getting stock price data for ADP from 2000-01-01 to 2024-10-23
# 2024-10-23 20:46:27,865, data_manager.py, 109, INFO, Getting stock price data for ADP from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:46:28,510, data_manager.py, 83, INFO, Saving data for ADP by year
# 2024-10-23 20:46:28,510, data_manager.py, 83, INFO, Saving data for ADP by year
# 2024-10-23 20:46:30,668, data_manager.py, 73, INFO, Processing ticker AZO
# 2024-10-23 20:46:30,668, data_manager.py, 73, INFO, Processing ticker AZO
# 2024-10-23 20:46:30,671, data_manager.py, 109, INFO, Getting stock price data for AZO from 2000-01-01 to 2024-10-23
# 2024-10-23 20:46:30,671, data_manager.py, 109, INFO, Getting stock price data for AZO from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:46:31,158, data_manager.py, 83, INFO, Saving data for AZO by year
# 2024-10-23 20:46:31,158, data_manager.py, 83, INFO, Saving data for AZO by year
# 2024-10-23 20:46:33,414, data_manager.py, 73, INFO, Processing ticker AVB
# 2024-10-23 20:46:33,414, data_manager.py, 73, INFO, Processing ticker AVB
# 2024-10-23 20:46:33,417, data_manager.py, 109, INFO, Getting stock price data for AVB from 2000-01-01 to 2024-10-23
# 2024-10-23 20:46:33,417, data_manager.py, 109, INFO, Getting stock price data for AVB from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:46:34,001, data_manager.py, 83, INFO, Saving data for AVB by year
# 2024-10-23 20:46:34,001, data_manager.py, 83, INFO, Saving data for AVB by year
# 2024-10-23 20:46:36,140, data_manager.py, 73, INFO, Processing ticker AVY
# 2024-10-23 20:46:36,140, data_manager.py, 73, INFO, Processing ticker AVY
# 2024-10-23 20:46:36,143, data_manager.py, 109, INFO, Getting stock price data for AVY from 2000-01-01 to 2024-10-23
# 2024-10-23 20:46:36,143, data_manager.py, 109, INFO, Getting stock price data for AVY from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:46:36,771, data_manager.py, 83, INFO, Saving data for AVY by year
# 2024-10-23 20:46:36,771, data_manager.py, 83, INFO, Saving data for AVY by year
# 2024-10-23 20:46:39,124, data_manager.py, 73, INFO, Processing ticker AXON
# 2024-10-23 20:46:39,124, data_manager.py, 73, INFO, Processing ticker AXON
# 2024-10-23 20:46:39,127, data_manager.py, 109, INFO, Getting stock price data for AXON from 2000-01-01 to 2024-10-23
# 2024-10-23 20:46:39,127, data_manager.py, 109, INFO, Getting stock price data for AXON from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:46:39,569, data_manager.py, 83, INFO, Saving data for AXON by year
# 2024-10-23 20:46:39,569, data_manager.py, 83, INFO, Saving data for AXON by year
# 2024-10-23 20:46:41,768, data_manager.py, 73, INFO, Processing ticker BKR
# 2024-10-23 20:46:41,768, data_manager.py, 73, INFO, Processing ticker BKR
# 2024-10-23 20:46:41,771, data_manager.py, 109, INFO, Getting stock price data for BKR from 2000-01-01 to 2024-10-23
# 2024-10-23 20:46:41,771, data_manager.py, 109, INFO, Getting stock price data for BKR from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:46:42,406, data_manager.py, 83, INFO, Saving data for BKR by year
# 2024-10-23 20:46:42,406, data_manager.py, 83, INFO, Saving data for BKR by year
# 2024-10-23 20:46:45,167, data_manager.py, 73, INFO, Processing ticker BALL
# 2024-10-23 20:46:45,167, data_manager.py, 73, INFO, Processing ticker BALL
# 2024-10-23 20:46:45,170, data_manager.py, 109, INFO, Getting stock price data for BALL from 2000-01-01 to 2024-10-23
# 2024-10-23 20:46:45,170, data_manager.py, 109, INFO, Getting stock price data for BALL from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:46:45,892, data_manager.py, 83, INFO, Saving data for BALL by year
# 2024-10-23 20:46:45,892, data_manager.py, 83, INFO, Saving data for BALL by year
# 2024-10-23 20:46:48,388, data_manager.py, 73, INFO, Processing ticker BAC
# 2024-10-23 20:46:48,388, data_manager.py, 73, INFO, Processing ticker BAC
# 2024-10-23 20:46:48,393, data_manager.py, 109, INFO, Getting stock price data for BAC from 2000-01-01 to 2024-10-23
# 2024-10-23 20:46:48,393, data_manager.py, 109, INFO, Getting stock price data for BAC from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:46:49,072, data_manager.py, 83, INFO, Saving data for BAC by year
# 2024-10-23 20:46:49,072, data_manager.py, 83, INFO, Saving data for BAC by year
# 2024-10-23 20:46:51,617, data_manager.py, 73, INFO, Processing ticker BK
# 2024-10-23 20:46:51,617, data_manager.py, 73, INFO, Processing ticker BK
# 2024-10-23 20:46:51,620, data_manager.py, 109, INFO, Getting stock price data for BK from 2000-01-01 to 2024-10-23
# 2024-10-23 20:46:51,620, data_manager.py, 109, INFO, Getting stock price data for BK from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:46:52,232, data_manager.py, 83, INFO, Saving data for BK by year
# 2024-10-23 20:46:52,232, data_manager.py, 83, INFO, Saving data for BK by year
# 2024-10-23 20:46:54,513, data_manager.py, 73, INFO, Processing ticker BBWI
# 2024-10-23 20:46:54,513, data_manager.py, 73, INFO, Processing ticker BBWI
# 2024-10-23 20:46:54,517, data_manager.py, 109, INFO, Getting stock price data for BBWI from 2000-01-01 to 2024-10-23
# 2024-10-23 20:46:54,517, data_manager.py, 109, INFO, Getting stock price data for BBWI from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:46:55,211, data_manager.py, 83, INFO, Saving data for BBWI by year
# 2024-10-23 20:46:55,211, data_manager.py, 83, INFO, Saving data for BBWI by year
# 2024-10-23 20:46:57,351, data_manager.py, 73, INFO, Processing ticker BAX
# 2024-10-23 20:46:57,351, data_manager.py, 73, INFO, Processing ticker BAX
# 2024-10-23 20:46:57,354, data_manager.py, 109, INFO, Getting stock price data for BAX from 2000-01-01 to 2024-10-23
# 2024-10-23 20:46:57,354, data_manager.py, 109, INFO, Getting stock price data for BAX from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:46:58,078, data_manager.py, 83, INFO, Saving data for BAX by year
# 2024-10-23 20:46:58,078, data_manager.py, 83, INFO, Saving data for BAX by year
# 2024-10-23 20:47:00,425, data_manager.py, 73, INFO, Processing ticker BDX
# 2024-10-23 20:47:00,425, data_manager.py, 73, INFO, Processing ticker BDX
# 2024-10-23 20:47:00,428, data_manager.py, 109, INFO, Getting stock price data for BDX from 2000-01-01 to 2024-10-23
# 2024-10-23 20:47:00,428, data_manager.py, 109, INFO, Getting stock price data for BDX from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:47:01,123, data_manager.py, 83, INFO, Saving data for BDX by year
# 2024-10-23 20:47:01,123, data_manager.py, 83, INFO, Saving data for BDX by year
# 2024-10-23 20:47:03,713, data_manager.py, 73, INFO, Processing ticker BRK.B
# 2024-10-23 20:47:03,713, data_manager.py, 73, INFO, Processing ticker BRK.B
# 2024-10-23 20:47:03,715, data_manager.py, 109, INFO, Getting stock price data for BRK.B from 2000-01-01 to 2024-10-23
# 2024-10-23 20:47:03,715, data_manager.py, 109, INFO, Getting stock price data for BRK.B from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['BRK.B']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# 2024-10-23 20:47:05,147, data_manager.py, 83, INFO, Saving data for BRK.B by year
# 2024-10-23 20:47:05,147, data_manager.py, 83, INFO, Saving data for BRK.B by year
# 2024-10-23 20:47:05,160, data_manager.py, 101, WARNING, No data found for BRK.B
# 2024-10-23 20:47:05,160, data_manager.py, 101, WARNING, No data found for BRK.B
# 2024-10-23 20:47:05,164, data_manager.py, 73, INFO, Processing ticker BBY
# 2024-10-23 20:47:05,164, data_manager.py, 73, INFO, Processing ticker BBY
# 2024-10-23 20:47:05,180, data_manager.py, 109, INFO, Getting stock price data for BBY from 2000-01-01 to 2024-10-23
# 2024-10-23 20:47:05,180, data_manager.py, 109, INFO, Getting stock price data for BBY from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:47:05,880, data_manager.py, 83, INFO, Saving data for BBY by year
# 2024-10-23 20:47:05,880, data_manager.py, 83, INFO, Saving data for BBY by year
# 2024-10-23 20:47:08,349, data_manager.py, 73, INFO, Processing ticker BIO
# 2024-10-23 20:47:08,349, data_manager.py, 73, INFO, Processing ticker BIO
# 2024-10-23 20:47:08,352, data_manager.py, 109, INFO, Getting stock price data for BIO from 2000-01-01 to 2024-10-23
# 2024-10-23 20:47:08,352, data_manager.py, 109, INFO, Getting stock price data for BIO from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:47:08,833, data_manager.py, 83, INFO, Saving data for BIO by year
# 2024-10-23 20:47:08,833, data_manager.py, 83, INFO, Saving data for BIO by year
# 2024-10-23 20:47:11,268, data_manager.py, 73, INFO, Processing ticker TECH
# 2024-10-23 20:47:11,268, data_manager.py, 73, INFO, Processing ticker TECH
# 2024-10-23 20:47:11,272, data_manager.py, 109, INFO, Getting stock price data for TECH from 2000-01-01 to 2024-10-23
# 2024-10-23 20:47:11,272, data_manager.py, 109, INFO, Getting stock price data for TECH from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:47:11,877, data_manager.py, 83, INFO, Saving data for TECH by year
# 2024-10-23 20:47:11,877, data_manager.py, 83, INFO, Saving data for TECH by year
# 2024-10-23 20:47:14,297, data_manager.py, 73, INFO, Processing ticker BIIB
# 2024-10-23 20:47:14,297, data_manager.py, 73, INFO, Processing ticker BIIB
# 2024-10-23 20:47:14,299, data_manager.py, 109, INFO, Getting stock price data for BIIB from 2000-01-01 to 2024-10-23
# 2024-10-23 20:47:14,299, data_manager.py, 109, INFO, Getting stock price data for BIIB from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:47:14,795, data_manager.py, 83, INFO, Saving data for BIIB by year
# 2024-10-23 20:47:14,795, data_manager.py, 83, INFO, Saving data for BIIB by year
# 2024-10-23 20:47:17,147, data_manager.py, 73, INFO, Processing ticker BLK
# 2024-10-23 20:47:17,147, data_manager.py, 73, INFO, Processing ticker BLK
# 2024-10-23 20:47:17,150, data_manager.py, 109, INFO, Getting stock price data for BLK from 2000-01-01 to 2024-10-23
# 2024-10-23 20:47:17,150, data_manager.py, 109, INFO, Getting stock price data for BLK from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:47:17,728, data_manager.py, 83, INFO, Saving data for BLK by year
# 2024-10-23 20:47:17,728, data_manager.py, 83, INFO, Saving data for BLK by year
# 2024-10-23 20:47:20,252, data_manager.py, 73, INFO, Processing ticker BX
# 2024-10-23 20:47:20,252, data_manager.py, 73, INFO, Processing ticker BX
# 2024-10-23 20:47:20,257, data_manager.py, 109, INFO, Getting stock price data for BX from 2000-01-01 to 2024-10-23
# 2024-10-23 20:47:20,257, data_manager.py, 109, INFO, Getting stock price data for BX from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:47:20,650, data_manager.py, 83, INFO, Saving data for BX by year
# 2024-10-23 20:47:20,650, data_manager.py, 83, INFO, Saving data for BX by year
# 2024-10-23 20:47:22,457, data_manager.py, 73, INFO, Processing ticker BA
# 2024-10-23 20:47:22,457, data_manager.py, 73, INFO, Processing ticker BA
# 2024-10-23 20:47:22,459, data_manager.py, 109, INFO, Getting stock price data for BA from 2000-01-01 to 2024-10-23
# 2024-10-23 20:47:22,459, data_manager.py, 109, INFO, Getting stock price data for BA from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:47:23,092, data_manager.py, 83, INFO, Saving data for BA by year
# 2024-10-23 20:47:23,092, data_manager.py, 83, INFO, Saving data for BA by year
# 2024-10-23 20:47:25,492, data_manager.py, 73, INFO, Processing ticker BKNG
# 2024-10-23 20:47:25,492, data_manager.py, 73, INFO, Processing ticker BKNG
# 2024-10-23 20:47:25,496, data_manager.py, 109, INFO, Getting stock price data for BKNG from 2000-01-01 to 2024-10-23
# 2024-10-23 20:47:25,496, data_manager.py, 109, INFO, Getting stock price data for BKNG from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:47:26,158, data_manager.py, 83, INFO, Saving data for BKNG by year
# 2024-10-23 20:47:26,158, data_manager.py, 83, INFO, Saving data for BKNG by year
# 2024-10-23 20:47:28,663, data_manager.py, 73, INFO, Processing ticker BWA
# 2024-10-23 20:47:28,663, data_manager.py, 73, INFO, Processing ticker BWA
# 2024-10-23 20:47:28,667, data_manager.py, 109, INFO, Getting stock price data for BWA from 2000-01-01 to 2024-10-23
# 2024-10-23 20:47:28,667, data_manager.py, 109, INFO, Getting stock price data for BWA from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:47:29,408, data_manager.py, 83, INFO, Saving data for BWA by year
# 2024-10-23 20:47:29,408, data_manager.py, 83, INFO, Saving data for BWA by year
# 2024-10-23 20:47:32,730, data_manager.py, 73, INFO, Processing ticker BXP
# 2024-10-23 20:47:32,730, data_manager.py, 73, INFO, Processing ticker BXP
# 2024-10-23 20:47:32,734, data_manager.py, 109, INFO, Getting stock price data for BXP from 2000-01-01 to 2024-10-23
# 2024-10-23 20:47:32,734, data_manager.py, 109, INFO, Getting stock price data for BXP from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:47:33,377, data_manager.py, 83, INFO, Saving data for BXP by year
# 2024-10-23 20:47:33,377, data_manager.py, 83, INFO, Saving data for BXP by year
# 2024-10-23 20:47:36,468, data_manager.py, 73, INFO, Processing ticker BSX
# 2024-10-23 20:47:36,468, data_manager.py, 73, INFO, Processing ticker BSX
# 2024-10-23 20:47:36,471, data_manager.py, 109, INFO, Getting stock price data for BSX from 2000-01-01 to 2024-10-23
# 2024-10-23 20:47:36,471, data_manager.py, 109, INFO, Getting stock price data for BSX from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:47:36,895, data_manager.py, 83, INFO, Saving data for BSX by year
# 2024-10-23 20:47:36,895, data_manager.py, 83, INFO, Saving data for BSX by year
# 2024-10-23 20:47:39,595, data_manager.py, 73, INFO, Processing ticker BMY
# 2024-10-23 20:47:39,595, data_manager.py, 73, INFO, Processing ticker BMY
# 2024-10-23 20:47:39,599, data_manager.py, 109, INFO, Getting stock price data for BMY from 2000-01-01 to 2024-10-23
# 2024-10-23 20:47:39,599, data_manager.py, 109, INFO, Getting stock price data for BMY from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:47:40,350, data_manager.py, 83, INFO, Saving data for BMY by year
# 2024-10-23 20:47:40,350, data_manager.py, 83, INFO, Saving data for BMY by year
# 2024-10-23 20:47:43,030, data_manager.py, 73, INFO, Processing ticker AVGO
# 2024-10-23 20:47:43,030, data_manager.py, 73, INFO, Processing ticker AVGO
# 2024-10-23 20:47:43,038, data_manager.py, 109, INFO, Getting stock price data for AVGO from 2000-01-01 to 2024-10-23
# 2024-10-23 20:47:43,038, data_manager.py, 109, INFO, Getting stock price data for AVGO from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:47:43,571, data_manager.py, 83, INFO, Saving data for AVGO by year
# 2024-10-23 20:47:43,571, data_manager.py, 83, INFO, Saving data for AVGO by year
# 2024-10-23 20:47:45,400, data_manager.py, 73, INFO, Processing ticker BR
# 2024-10-23 20:47:45,400, data_manager.py, 73, INFO, Processing ticker BR
# 2024-10-23 20:47:45,404, data_manager.py, 109, INFO, Getting stock price data for BR from 2000-01-01 to 2024-10-23
# 2024-10-23 20:47:45,404, data_manager.py, 109, INFO, Getting stock price data for BR from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 20:47:45,839, data_manager.py, 83, INFO, Saving data for BR by year
# 2024-10-23 20:47:45,839, data_manager.py, 83, INFO, Saving data for BR by year
# 2024-10-23 20:47:47,589, data_manager.py, 73, INFO, Processing ticker BRO
# 2024-10-23 20:47:47,589, data_manager.py, 73, INFO, Processing ticker BRO
# ...
# 2024-10-23 21:08:03,823, data_manager.py, 109, INFO, Getting stock price data for WAB from 2000-01-01 to 2024-10-23
# 2024-10-23 21:08:03,823, data_manager.py, 109, INFO, Getting stock price data for WAB from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 21:08:04,512, data_manager.py, 83, INFO, Saving data for WAB by year
# 2024-10-23 21:08:04,512, data_manager.py, 83, INFO, Saving data for WAB by year
# 2024-10-23 21:08:07,301, data_manager.py, 73, INFO, Processing ticker WBA
# 2024-10-23 21:08:07,301, data_manager.py, 73, INFO, Processing ticker WBA
# 2024-10-23 21:08:07,303, data_manager.py, 109, INFO, Getting stock price data for WBA from 2000-01-01 to 2024-10-23
# 2024-10-23 21:08:07,303, data_manager.py, 109, INFO, Getting stock price data for WBA from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 21:08:07,917, data_manager.py, 83, INFO, Saving data for WBA by year
# 2024-10-23 21:08:07,917, data_manager.py, 83, INFO, Saving data for WBA by year
# 2024-10-23 21:08:10,733, data_manager.py, 73, INFO, Processing ticker WMT
# 2024-10-23 21:08:10,733, data_manager.py, 73, INFO, Processing ticker WMT
# 2024-10-23 21:08:10,737, data_manager.py, 109, INFO, Getting stock price data for WMT from 2000-01-01 to 2024-10-23
# 2024-10-23 21:08:10,737, data_manager.py, 109, INFO, Getting stock price data for WMT from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 21:08:11,505, data_manager.py, 83, INFO, Saving data for WMT by year
# 2024-10-23 21:08:11,505, data_manager.py, 83, INFO, Saving data for WMT by year
# 2024-10-23 21:08:14,577, data_manager.py, 73, INFO, Processing ticker DIS
# 2024-10-23 21:08:14,577, data_manager.py, 73, INFO, Processing ticker DIS
# 2024-10-23 21:08:14,584, data_manager.py, 109, INFO, Getting stock price data for DIS from 2000-01-01 to 2024-10-23
# 2024-10-23 21:08:14,584, data_manager.py, 109, INFO, Getting stock price data for DIS from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 21:08:15,440, data_manager.py, 83, INFO, Saving data for DIS by year
# 2024-10-23 21:08:15,440, data_manager.py, 83, INFO, Saving data for DIS by year
# 2024-10-23 21:08:18,268, data_manager.py, 73, INFO, Processing ticker WBD
# 2024-10-23 21:08:18,268, data_manager.py, 73, INFO, Processing ticker WBD
# 2024-10-23 21:08:18,271, data_manager.py, 109, INFO, Getting stock price data for WBD from 2000-01-01 to 2024-10-23
# 2024-10-23 21:08:18,271, data_manager.py, 109, INFO, Getting stock price data for WBD from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 21:08:18,780, data_manager.py, 83, INFO, Saving data for WBD by year
# 2024-10-23 21:08:18,780, data_manager.py, 83, INFO, Saving data for WBD by year
# 2024-10-23 21:08:20,729, data_manager.py, 73, INFO, Processing ticker WM
# 2024-10-23 21:08:20,729, data_manager.py, 73, INFO, Processing ticker WM
# 2024-10-23 21:08:20,732, data_manager.py, 109, INFO, Getting stock price data for WM from 2000-01-01 to 2024-10-23
# 2024-10-23 21:08:20,732, data_manager.py, 109, INFO, Getting stock price data for WM from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 21:08:21,306, data_manager.py, 83, INFO, Saving data for WM by year
# 2024-10-23 21:08:21,306, data_manager.py, 83, INFO, Saving data for WM by year
# 2024-10-23 21:08:23,779, data_manager.py, 73, INFO, Processing ticker WAT
# 2024-10-23 21:08:23,779, data_manager.py, 73, INFO, Processing ticker WAT
# 2024-10-23 21:08:23,783, data_manager.py, 109, INFO, Getting stock price data for WAT from 2000-01-01 to 2024-10-23
# 2024-10-23 21:08:23,783, data_manager.py, 109, INFO, Getting stock price data for WAT from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 21:08:24,272, data_manager.py, 83, INFO, Saving data for WAT by year
# 2024-10-23 21:08:24,272, data_manager.py, 83, INFO, Saving data for WAT by year
# 2024-10-23 21:08:26,907, data_manager.py, 73, INFO, Processing ticker WEC
# 2024-10-23 21:08:26,907, data_manager.py, 73, INFO, Processing ticker WEC
# 2024-10-23 21:08:26,913, data_manager.py, 109, INFO, Getting stock price data for WEC from 2000-01-01 to 2024-10-23
# 2024-10-23 21:08:26,913, data_manager.py, 109, INFO, Getting stock price data for WEC from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 21:08:27,506, data_manager.py, 83, INFO, Saving data for WEC by year
# 2024-10-23 21:08:27,506, data_manager.py, 83, INFO, Saving data for WEC by year
# 2024-10-23 21:08:30,101, data_manager.py, 73, INFO, Processing ticker WFC
# 2024-10-23 21:08:30,101, data_manager.py, 73, INFO, Processing ticker WFC
# 2024-10-23 21:08:30,104, data_manager.py, 109, INFO, Getting stock price data for WFC from 2000-01-01 to 2024-10-23
# 2024-10-23 21:08:30,104, data_manager.py, 109, INFO, Getting stock price data for WFC from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 21:08:30,835, data_manager.py, 83, INFO, Saving data for WFC by year
# 2024-10-23 21:08:30,835, data_manager.py, 83, INFO, Saving data for WFC by year
# 2024-10-23 21:08:33,075, data_manager.py, 73, INFO, Processing ticker WELL
# 2024-10-23 21:08:33,075, data_manager.py, 73, INFO, Processing ticker WELL
# 2024-10-23 21:08:33,078, data_manager.py, 109, INFO, Getting stock price data for WELL from 2000-01-01 to 2024-10-23
# 2024-10-23 21:08:33,078, data_manager.py, 109, INFO, Getting stock price data for WELL from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 21:08:33,646, data_manager.py, 83, INFO, Saving data for WELL by year
# 2024-10-23 21:08:33,646, data_manager.py, 83, INFO, Saving data for WELL by year
# 2024-10-23 21:08:36,095, data_manager.py, 73, INFO, Processing ticker WST
# 2024-10-23 21:08:36,095, data_manager.py, 73, INFO, Processing ticker WST
# 2024-10-23 21:08:36,101, data_manager.py, 109, INFO, Getting stock price data for WST from 2000-01-01 to 2024-10-23
# 2024-10-23 21:08:36,101, data_manager.py, 109, INFO, Getting stock price data for WST from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 21:08:36,704, data_manager.py, 83, INFO, Saving data for WST by year
# 2024-10-23 21:08:36,704, data_manager.py, 83, INFO, Saving data for WST by year
# 2024-10-23 21:08:39,291, data_manager.py, 73, INFO, Processing ticker WDC
# 2024-10-23 21:08:39,291, data_manager.py, 73, INFO, Processing ticker WDC
# 2024-10-23 21:08:39,295, data_manager.py, 109, INFO, Getting stock price data for WDC from 2000-01-01 to 2024-10-23
# 2024-10-23 21:08:39,295, data_manager.py, 109, INFO, Getting stock price data for WDC from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 21:08:39,710, data_manager.py, 83, INFO, Saving data for WDC by year
# 2024-10-23 21:08:39,710, data_manager.py, 83, INFO, Saving data for WDC by year
# 2024-10-23 21:08:42,783, data_manager.py, 73, INFO, Processing ticker WRK
# 2024-10-23 21:08:42,783, data_manager.py, 73, INFO, Processing ticker WRK
# 2024-10-23 21:08:42,787, data_manager.py, 109, INFO, Getting stock price data for WRK from 2000-01-01 to 2024-10-23
# 2024-10-23 21:08:42,787, data_manager.py, 109, INFO, Getting stock price data for WRK from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['WRK']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# 2024-10-23 21:08:44,252, data_manager.py, 83, INFO, Saving data for WRK by year
# 2024-10-23 21:08:44,252, data_manager.py, 83, INFO, Saving data for WRK by year
# 2024-10-23 21:08:44,256, data_manager.py, 101, WARNING, No data found for WRK
# 2024-10-23 21:08:44,256, data_manager.py, 101, WARNING, No data found for WRK
# 2024-10-23 21:08:44,265, data_manager.py, 73, INFO, Processing ticker WY
# 2024-10-23 21:08:44,265, data_manager.py, 73, INFO, Processing ticker WY
# 2024-10-23 21:08:44,269, data_manager.py, 109, INFO, Getting stock price data for WY from 2000-01-01 to 2024-10-23
# 2024-10-23 21:08:44,269, data_manager.py, 109, INFO, Getting stock price data for WY from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 21:08:44,945, data_manager.py, 83, INFO, Saving data for WY by year
# 2024-10-23 21:08:44,945, data_manager.py, 83, INFO, Saving data for WY by year
# 2024-10-23 21:08:48,226, data_manager.py, 73, INFO, Processing ticker WHR
# 2024-10-23 21:08:48,226, data_manager.py, 73, INFO, Processing ticker WHR
# 2024-10-23 21:08:48,230, data_manager.py, 109, INFO, Getting stock price data for WHR from 2000-01-01 to 2024-10-23
# 2024-10-23 21:08:48,230, data_manager.py, 109, INFO, Getting stock price data for WHR from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 21:08:48,856, data_manager.py, 83, INFO, Saving data for WHR by year
# 2024-10-23 21:08:48,856, data_manager.py, 83, INFO, Saving data for WHR by year
# 2024-10-23 21:08:51,782, data_manager.py, 73, INFO, Processing ticker WMB
# 2024-10-23 21:08:51,782, data_manager.py, 73, INFO, Processing ticker WMB
# 2024-10-23 21:08:51,785, data_manager.py, 109, INFO, Getting stock price data for WMB from 2000-01-01 to 2024-10-23
# 2024-10-23 21:08:51,785, data_manager.py, 109, INFO, Getting stock price data for WMB from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 21:08:52,588, data_manager.py, 83, INFO, Saving data for WMB by year
# 2024-10-23 21:08:52,588, data_manager.py, 83, INFO, Saving data for WMB by year
# 2024-10-23 21:08:55,403, data_manager.py, 73, INFO, Processing ticker WTW
# 2024-10-23 21:08:55,403, data_manager.py, 73, INFO, Processing ticker WTW
# 2024-10-23 21:08:55,406, data_manager.py, 109, INFO, Getting stock price data for WTW from 2000-01-01 to 2024-10-23
# 2024-10-23 21:08:55,406, data_manager.py, 109, INFO, Getting stock price data for WTW from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 21:08:56,006, data_manager.py, 83, INFO, Saving data for WTW by year
# 2024-10-23 21:08:56,006, data_manager.py, 83, INFO, Saving data for WTW by year
# 2024-10-23 21:08:59,175, data_manager.py, 73, INFO, Processing ticker GWW
# 2024-10-23 21:08:59,175, data_manager.py, 73, INFO, Processing ticker GWW
# 2024-10-23 21:08:59,179, data_manager.py, 109, INFO, Getting stock price data for GWW from 2000-01-01 to 2024-10-23
# 2024-10-23 21:08:59,179, data_manager.py, 109, INFO, Getting stock price data for GWW from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 21:08:59,705, data_manager.py, 83, INFO, Saving data for GWW by year
# 2024-10-23 21:08:59,705, data_manager.py, 83, INFO, Saving data for GWW by year
# 2024-10-23 21:09:02,241, data_manager.py, 73, INFO, Processing ticker WYNN
# 2024-10-23 21:09:02,241, data_manager.py, 73, INFO, Processing ticker WYNN
# 2024-10-23 21:09:02,245, data_manager.py, 109, INFO, Getting stock price data for WYNN from 2000-01-01 to 2024-10-23
# 2024-10-23 21:09:02,245, data_manager.py, 109, INFO, Getting stock price data for WYNN from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 21:09:02,739, data_manager.py, 83, INFO, Saving data for WYNN by year
# 2024-10-23 21:09:02,739, data_manager.py, 83, INFO, Saving data for WYNN by year
# 2024-10-23 21:09:05,104, data_manager.py, 73, INFO, Processing ticker XEL
# 2024-10-23 21:09:05,104, data_manager.py, 73, INFO, Processing ticker XEL
# 2024-10-23 21:09:05,107, data_manager.py, 109, INFO, Getting stock price data for XEL from 2000-01-01 to 2024-10-23
# 2024-10-23 21:09:05,107, data_manager.py, 109, INFO, Getting stock price data for XEL from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 21:09:05,687, data_manager.py, 83, INFO, Saving data for XEL by year
# 2024-10-23 21:09:05,687, data_manager.py, 83, INFO, Saving data for XEL by year
# 2024-10-23 21:09:08,359, data_manager.py, 73, INFO, Processing ticker XYL
# 2024-10-23 21:09:08,359, data_manager.py, 73, INFO, Processing ticker XYL
# 2024-10-23 21:09:08,362, data_manager.py, 109, INFO, Getting stock price data for XYL from 2000-01-01 to 2024-10-23
# 2024-10-23 21:09:08,362, data_manager.py, 109, INFO, Getting stock price data for XYL from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 21:09:08,783, data_manager.py, 83, INFO, Saving data for XYL by year
# 2024-10-23 21:09:08,783, data_manager.py, 83, INFO, Saving data for XYL by year
# 2024-10-23 21:09:10,974, data_manager.py, 73, INFO, Processing ticker YUM
# 2024-10-23 21:09:10,974, data_manager.py, 73, INFO, Processing ticker YUM
# 2024-10-23 21:09:10,977, data_manager.py, 109, INFO, Getting stock price data for YUM from 2000-01-01 to 2024-10-23
# 2024-10-23 21:09:10,977, data_manager.py, 109, INFO, Getting stock price data for YUM from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 21:09:11,480, data_manager.py, 83, INFO, Saving data for YUM by year
# 2024-10-23 21:09:11,480, data_manager.py, 83, INFO, Saving data for YUM by year
# 2024-10-23 21:09:13,444, data_manager.py, 73, INFO, Processing ticker ZBRA
# 2024-10-23 21:09:13,444, data_manager.py, 73, INFO, Processing ticker ZBRA
# 2024-10-23 21:09:13,448, data_manager.py, 109, INFO, Getting stock price data for ZBRA from 2000-01-01 to 2024-10-23
# 2024-10-23 21:09:13,448, data_manager.py, 109, INFO, Getting stock price data for ZBRA from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 21:09:13,977, data_manager.py, 83, INFO, Saving data for ZBRA by year
# 2024-10-23 21:09:13,977, data_manager.py, 83, INFO, Saving data for ZBRA by year
# 2024-10-23 21:09:16,073, data_manager.py, 73, INFO, Processing ticker ZBH
# 2024-10-23 21:09:16,073, data_manager.py, 73, INFO, Processing ticker ZBH
# 2024-10-23 21:09:16,076, data_manager.py, 109, INFO, Getting stock price data for ZBH from 2000-01-01 to 2024-10-23
# 2024-10-23 21:09:16,076, data_manager.py, 109, INFO, Getting stock price data for ZBH from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 21:09:16,603, data_manager.py, 83, INFO, Saving data for ZBH by year
# 2024-10-23 21:09:16,603, data_manager.py, 83, INFO, Saving data for ZBH by year
# 2024-10-23 21:09:18,700, data_manager.py, 73, INFO, Processing ticker ZION
# 2024-10-23 21:09:18,700, data_manager.py, 73, INFO, Processing ticker ZION
# 2024-10-23 21:09:18,703, data_manager.py, 109, INFO, Getting stock price data for ZION from 2000-01-01 to 2024-10-23
# 2024-10-23 21:09:18,703, data_manager.py, 109, INFO, Getting stock price data for ZION from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 21:09:19,300, data_manager.py, 83, INFO, Saving data for ZION by year
# 2024-10-23 21:09:19,300, data_manager.py, 83, INFO, Saving data for ZION by year
# 2024-10-23 21:09:21,798, data_manager.py, 73, INFO, Processing ticker ZTS
# 2024-10-23 21:09:21,798, data_manager.py, 73, INFO, Processing ticker ZTS
# 2024-10-23 21:09:21,800, data_manager.py, 109, INFO, Getting stock price data for ZTS from 2000-01-01 to 2024-10-23
# 2024-10-23 21:09:21,800, data_manager.py, 109, INFO, Getting stock price data for ZTS from 2000-01-01 to 2024-10-23
# [*********************100%%**********************]  1 of 1 completed
# 2024-10-23 21:09:22,230, data_manager.py, 83, INFO, Saving data for ZTS by year
# 2024-10-23 21:09:22,230, data_manager.py, 83, INFO, Saving data for ZTS by year

# %% [markdown]
# Finally, add features to our data set and save to a *feature store*.

# %%
dm.featurize()
# Out:
# 2024-10-23 21:09:35,641, data_manager.py, 121, INFO, Creating features data.
# 2024-10-23 21:09:35,641, data_manager.py, 121, INFO, Creating features data.
# 2024-10-23 21:09:35,645, data_manager.py, 132, INFO, Loading price data from ../../05_src/data/prices/
# 2024-10-23 21:09:35,645, data_manager.py, 132, INFO, Loading price data from ../../05_src/data/prices/
# c:\Users\Alexander\miniconda3\envs\dsi_participant\lib\site-packages\dask\dataframe\core.py:5517: UserWarning: New index has same name as existing, this is a no-op.
#   warnings.warn(
# 2024-10-23 21:09:45,645, data_manager.py, 140, INFO, Creating features
# 2024-10-23 21:09:45,645, data_manager.py, 140, INFO, Creating features
# c:\Users\Alexander\Documents\DSI\production\01_materials\labs\../../05_src\data_manager.py:142: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   features = (price_dd
# 2024-10-23 21:09:45,972, data_manager.py, 158, INFO, Creating target
# 2024-10-23 21:09:45,972, data_manager.py, 158, INFO, Creating target
# c:\Users\Alexander\Documents\DSI\production\01_materials\labs\../../05_src\data_manager.py:159: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   self.features = (self.features.groupby('ticker', group_keys=False).apply(
# 2024-10-23 21:09:46,117, data_manager.py, 168, INFO, Saving features to ../../05_src/data/features/stock_features.parquet
# 2024-10-23 21:09:46,117, data_manager.py, 168, INFO, Saving features to ../../05_src/data/features/stock_features.parquet
